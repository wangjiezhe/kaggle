# %% [markdown]
# 注释掉 `on_prediction_end`

# %%
from train import *

# %%
model = ResNet(models.regnet_x_3_2gf)
# Out:
# /usr/lib/python3.11/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
model.load_state_dict(torch.load("ResNetX_3_2GF_pretrained-epoch_8.pt"))
# Out:
# <All keys matched successfully>

# %%
logger = TensorBoardLogger(".", default_hp_metric=False)
data = LeavesData(batch_size=32)
trainer = pl.Trainer(max_epochs=1, logger=logger)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
predictions = trainer.predict(model, data)
# Out:
# 2024-01-05 00:08:00.735477: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-05 00:08:00.735515: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-05 00:08:00.754228: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
len(predictions)
# Out:
# 275

# %%
len(trainer.predict_loop.predictions)
# Out:
# 275

# %%
predictions[0]
# Out:
# tensor([ 49,  95, 161,   1, 161,  67, 101, 100, 161,  95, 174, 100,  67, 153,
#         101, 100, 101,  49, 101, 150, 168, 150,  67, 133,  53,  34,  89, 102,
#          60, 153,  84, 153])

# %%
trainer.predict_loop.predictions[0]
# Out:
# tensor([ 49,  95, 161,   1, 161,  67, 101, 100, 161,  95, 174, 100,  67, 153,
#         101, 100, 101,  49, 101, 150, 168, 150,  67, 133,  53,  34,  89, 102,
#          60, 153,  84, 153])

# %%
torch.stack(predictions).view(-1).tolist()
# Out:
# [49,
#  95,
#  161,
#  1,
#  161,
#  67,
#  101,
#  100,
#  161,
#  95,
#  174,
#  100,
#  67,
#  153,
#  101,
#  100,
#  101,
#  49,
#  101,
#  150,
#  168,
#  150,
#  67,
#  133,
#  53,
#  34,
#  89,
#  102,
#  60,
#  153,
#  84,
#  153,
#  72,
#  147,
#  49,
#  49,
#  71,
#  100,
#  168,
#  130,
#  100,
#  161,
#  161,
#  161,
#  161,
#  53,
#  49,
#  53,
#  150,
#  48,
#  105,
#  161,
#  161,
#  105,
#  99,
#  174,
#  72,
#  72,
#  49,
#  49,
#  49,
#  49,
#  161,
#  130,
#  49,
#  161,
#  101,
#  67,
#  49,
#  150,
#  130,
#  130,
#  43,
#  49,
#  174,
#  72,
#  95,
#  150,
#  146,
#  105,
#  101,
#  130,
#  5,
#  105,
#  168,
#  54,
#  162,
#  67,
#  103,
#  150,
#  49,
#  161,
#  49,
#  38,
#  49,
#  49,
#  101,
#  153,
#  60,
#  5,
#  107,
#  161,
#  67,
#  49,
#  49,
#  153,
#  150,
#  105,
#  150,
#  60,
#  53,
#  67,
#  161,
#  49,
#  73,
#  168,
#  161,
#  150,
#  72,
#  72,
#  130,
#  99,
#  153,
#  161,
#  130,
#  75,
#  71,
#  105,
#  174,
#  67,
#  158,
#  161,
# ...

# %%
trainer.fit(model, data)
# Out:
# 2024-01-05 00:18:02.089908: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-05 00:18:02.089945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-05 00:18:02.107847: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name             | Type                      | Params
# ---------------------------------------------------------------
# 0 | train_acc        | MulticlassAccuracy        | 0
# 1 | val_acc          | MulticlassAccuracy        | 0
# 2 | test_top1_acc    | MulticlassAccuracy        | 0
# ...

# %%
trainer.validate_loop.state_dict()
# Out:
# {'state_dict': {},
#  'batch_progress': {'total': {'ready': 0,
#    'completed': 0,
#    'started': 0,
#    'processed': 0},
#   'current': {'ready': 0, 'completed': 0, 'started': 0, 'processed': 0},
#   'is_last_batch': False}}

# %%
trainer.fit_loop.epoch_loop.state_dict()
# Out:
# {'state_dict': {'_batches_that_stepped': 505},
#  'batch_progress': {'total': {'ready': 505,
#    'completed': 505,
#    'started': 505,
#    'processed': 505},
#   'current': {'ready': 505,
#    'completed': 505,
#    'started': 505,
#    'processed': 505},
#   'is_last_batch': True},
#  'scheduler_progress': {'total': {'ready': 0, 'completed': 0},
#   'current': {'ready': 0, 'completed': 0}},
#  'automatic_optimization.state_dict': {},
#  'automatic_optimization.optim_progress': {'optimizer': {'step': {'total': {'ready': 505,
#      'completed': 505},
#     'current': {'ready': 505, 'completed': 505}},
#    'zero_grad': {'total': {'ready': 505, 'completed': 505, 'started': 505},
#     'current': {'ready': 505, 'completed': 505, 'started': 505}}}},
#  'manual_optimization.state_dict': {},
#  'manual_optimization.optim_step_progress': {'total': {'ready': 0,
#    'completed': 0},
#   'current': {'ready': 0, 'completed': 0}},
#  'val_loop.state_dict': {},
# ...

# %%
trainer.fit_loop.epoch_loop.val_loop.state_dict()
# Out:
# {'state_dict': {},
#  'batch_progress': {'total': {'ready': 56,
#    'completed': 56,
#    'started': 56,
#    'processed': 56},
#   'current': {'ready': 56, 'completed': 56, 'started': 56, 'processed': 56},
#   'is_last_batch': True}}
